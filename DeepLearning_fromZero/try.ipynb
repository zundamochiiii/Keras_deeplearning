# %%
#自分でニューラルネットワークを作ってみよう
import numpy as np

def sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x))

class NN():
    def __init__(self):
        #initialize

# %% [markdown]
# ## 参考URL
# Keras Documentation
# https://keras.io/ja/
#
# Chainer
# https://tutorials.chainer.org/ja/13_Basics_of_Neural_Networks.html#%E3%83%8B%E3%83%A5%E3%83%BC%E3%83%A9%E3%83%AB%E3%83%8D%E3%83%83%E3%83%88%E3%83%AF%E3%83%BC%E3%82%AF%E3%81%AE%E8%A8%93%E7%B7%B4

# %%
import pandas as pd

df = pd.read_csv("./Datasets/vgsales.csv")

df2 = df[df["Platform"]=="Wii"]
print(df2)

print("df:",df.shape,"\ndf2;",df2.shape)
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# ...      ...                                                ...      ...
# 16517  16520                       Teenage Mutant Ninja Turtles      Wii
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16581  16584                                          Fit & Fun      Wii
#
#          Year     Genre                     Publisher  NA_Sales  EU_Sales  \
# ...
